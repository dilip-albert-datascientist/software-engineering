# %% [raw]
# Created by Peichl, Thomas (GfK), last modified on 23. Nov 2020
#
# Google Cloud Training for Data Science provided by Google - Sept/ Oct 2020
#
# Session 1  - Google Cloud Overview for Data Science                   -  Monday, Sept. 28th    -  Agenda and Recording
# Session 2  - Google Cloud for Data Science - Deep Dive           -  Friday, Oct.  16th        - Agenda and Recording
# Session 3  - Google Cloud for Data Science - Deep Dive           -  Friday, Oct.  23rd       -  Agenda and Recording
#
# Feedback on GCP Training Sesions: Your feedback on GCP training sessions.pdf
# GCP Training on the Coursera E-Learning platform
# GCP Learning Paths, Certification and Learning Sources
#
#
# Google Cloud Training for Data Science provided by Google - Sept/ Oct 2020
#
# Google did some Google Cloud training for us.  You can find the agenda and the recordings below.
#
# Session 1  - Google Cloud Overview for Data Science                   -  Monday, Sept. 28th    -  Agenda and Recording
#
# Lecture - Google Cloud, Projects, Resource Management, and Access Control
#
# Lab - Create a project and a deep learning virtual machine (DLVM) using the Cloud Console. Quick experiments with Cloud Shell, and the gcloud command
#
# Lecture - Guided Tour of Google Cloud Services (with an emphasis on Data Science)
#
# Lab - Simple experiments with AI Platform, BigQuery, AutoML and Data Studio
#
# Conclusion, Q&A, Discussion
# Recordings:
#
# Part 1: https://web.microsoftstream.com/video/a04b0d1c-cef3-46f2-b101-397449472834
#
# Part 2: https://web.microsoftstream.com/video/f95202f1-c66c-4c81-b275-2723615c1e32
#
# Slides: mco.fyi/ds
#
# Session 2  - Google Cloud for Data Science - Deep Dive           -  Friday, Oct.  16th        - Agenda and Recording
#
# BigQuery - 60 mins (30/30 lecture/lab)
# Data Studio - 60 mins (30/30 lecture/lab)
# Recording https://web.microsoftstream.com/video/171a133d-fb6b-42cf-aec7-e91cf755a576
#
# Slides: mco.fyi/ds2
#
# Session 3  - Google Cloud for Data Science - Deep Dive           -  Friday, Oct.  23rd       -  Agenda and Recording
#
# AI Platform - 60 mins (30/30 lecture/lab)
#     Hub
#         Model sharing
#     Pipelines
#     Notebooks
# Other topics  - 60 mins (lecture & demos)
#     AutoML
#     PyCharm w/ Cloud Code
#     Workflow and Composer
#     Looker
#     Recordings
#
# Part 1: https://web.microsoftstream.com/video/3e2668b7-9db0-406e-9765-26c693f17347
#
# Part 2: https://web.microsoftstream.com/video/d90c3828-0b8e-4799-b0bd-9aba86d96020
#
# Slides: mco.fyi/ds2
#
# Feedback on GCP Training Sesions: Your feedback on GCP training sessions.pdf
# GCP Training on the Coursera E-Learning platform
# Coursera is an official training partner of Google for GCP and offers a wide range of courses.
#
# For everyone interested in GCP training, we have compiled in the following table the courses available at Coursera: 2020_06 Coursera for GfK GCP Collections.xlsx  You will find there the GCP course Collections
#
#     1. Infrastructure & Architecting
#
#     2. App Development & API's
#
#     3. Machine Learning & Data Engineering
#
#     4. Professional Skills
#
# If you would like to take one or more of these courses, please register on the GfK Coursera Waiting List. Coursera E-Learning - Sign-up for a 12-week Licence
#
# Sidenote: In case the course you have chosen is not yet activated on our GfK-Coursera training platform, please send a short information to: Peichl, Thomas (GfK)
#
# GCP Learning Paths, Certification and Learning Sources
#
#
# Google Cloud Learning Paths: Learning Paths Labs Brochure.pdf
#
# Google Cloud Training: https://cloud.google.com/training?#learning-paths
#
# Google Cloud Certification: https://cloud.google.com/certification
